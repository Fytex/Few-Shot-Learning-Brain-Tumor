# %% [markdown]
# Create Embedding Network

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import time
import numpy as np
import matplotlib.pyplot as plt
#!pip install tensorflow==2.9.1 # For EfficientNetB0
import tensorflow as tf
import math

import utils

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import vgg16, imagenet_utils
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.regularizers import l2
from tensorflow.keras.metrics import binary_crossentropy
from tensorflow.keras.layers import Dense, Flatten, Input, Lambda, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score
import itertools

from skimage import exposure

import logging
from tensorflow.keras.models import load_model

logger = tf.get_logger()
logger.setLevel(logging.ERROR)

print('Using:')
print('\t\u2022 TensorFlow version:', tf.__version__)
print('\t\u2022 tf.keras version:', tf.keras.__version__)
print('\t\u2022 Running on GPU' if tf.test.is_gpu_available() else '\t\u2022 GPU device not found. Running on CPU')
# Out:
# Using:
# 	• TensorFlow version: 2.12.0
# 	• tf.keras version: 2.12.0
# 	• Running on GPU

# %% [markdown]
# Load Dataset (Using 150x150)

# %%
""" load the datasets """

base_dir = os.path.join('dataset', 'pretrain4w')

train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

train_glioma_dir = os.path.join(train_dir, 'glioma_tumor')
train_meningioma_dir = os.path.join(train_dir, 'meningioma_tumor')
train_normal_dir = os.path.join(train_dir, 'no_tumor')
train_pituitary_dir = os.path.join(train_dir, 'pituitary_tumor')

val_glioma_dir = os.path.join(val_dir, 'glioma_tumor')
val_meningioma_dir = os.path.join(val_dir, 'meningioma_tumor')
val_normal_dir = os.path.join(val_dir, 'no_tumor')
val_pituitary_dir = os.path.join(val_dir, 'pituitary_tumor')

INPUT_SIZE = 150
BATCH_SIZE = 16

""" Investigate train - val datasets """

train_batches = ImageDataGenerator(rescale = 1 / 255.).flow_from_directory(train_dir,
                                                         target_size=(INPUT_SIZE,INPUT_SIZE),
                                                         class_mode='categorical',
                                                         shuffle=True,
                                                         seed=42,
                                                         batch_size=BATCH_SIZE)

val_batches = ImageDataGenerator(rescale = 1 / 255.).flow_from_directory(val_dir,
                                                         target_size=(INPUT_SIZE,INPUT_SIZE),
                                                         class_mode='categorical',
                                                         shuffle=True,
                                                         seed=42,
                                                         batch_size=BATCH_SIZE)

num_glioma_train = int(len(os.listdir(train_glioma_dir)))
num_meningioma_train = int(len(os.listdir(train_meningioma_dir)))
num_normal_train = int(len(os.listdir(train_normal_dir)))
num_pituitary_train = int(len(os.listdir(train_pituitary_dir)))

num_glioma_val = int(len(os.listdir(val_glioma_dir)))
num_meningioma_val = int(len(os.listdir(val_meningioma_dir)))
num_normal_val = int(len(os.listdir(val_normal_dir)))
num_pituitary_val = int(len(os.listdir(val_pituitary_dir)))

print('The dataset contains:')
print('\u2022 {} training images'.format(num_glioma_train + num_meningioma_train + num_normal_train + num_pituitary_train))
print('\u2022 {} validation images'.format(num_glioma_val + num_meningioma_val + num_normal_val + num_pituitary_val))

print('\nThe training set contains:')
print('\u2022 {} glioma images'.format(num_glioma_train))
print('\u2022 {} meningioma images'.format(num_meningioma_train))
print('\u2022 {} normal images'.format(num_normal_train))
print('\u2022 {} pituitary images'.format(num_pituitary_train))

print('\nThe validation set contains:')
print('\u2022 {} glioma images'.format(num_glioma_val))
print('\u2022 {} meningioma images'.format(num_meningioma_val))
print('\u2022 {} normal images'.format(num_normal_val))
print('\u2022 {} pituitary images'.format(num_pituitary_val))
# Out:
# Found 1372 images belonging to 4 classes.
# Found 40 images belonging to 4 classes.
# The dataset contains:
# • 1372 training images
# • 40 validation images
#
# The training set contains:
# • 343 glioma images
# • 343 meningioma images
# • 343 normal images
# • 343 pituitary images
#
# The validation set contains:
# • 10 glioma images
# • 10 meningioma images
# • 10 normal images
# • 10 pituitary images

# %%
MODEL_FNAME = 'embedding_network.h5'

tf.compat.v1.reset_default_graph()

tf.random.set_seed(0)
tf.keras.utils.set_random_seed(0)


""" Create the model """
    
base_model = vgg16.VGG16(weights='imagenet', include_top=False, input_shape=(INPUT_SIZE,INPUT_SIZE,3)) # loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9750 - Test: 0.94557
#base_model = EfficientNetB0(weights='imagenet',include_top=False,input_shape=(INPUT_SIZE,INPUT_SIZE,3)) # loss: 0.0312 - accuracy: 0.9920 - val_loss: 0.1799 - val_accuracy: 0.9250 - Test: 0.933673
#base_model = Xception(weights='imagenet', include_top=False, input_shape=(INPUT_SIZE,INPUT_SIZE,3)) # loss: 0.0335 - accuracy: 0.9978 - val_loss: 0.3005 - val_accuracy: 0.9000
#base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(INPUT_SIZE,INPUT_SIZE,3)) # loss: 0.0912 - accuracy: 0.9730 - val_loss: 0.1897 - val_accuracy: 0.9250
#base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(INPUT_SIZE,INPUT_SIZE,3)) # loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.2221 - val_accuracy: 0.9250
#base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(INPUT_SIZE,INPUT_SIZE,3)) # loss: 0.0028 - accuracy: 0.9985 - val_loss: 0.1825 - val_accuracy: 0.9250
#base_model = vgg19.VGG19(weights='imagenet', include_top=False, input_shape=(INPUT_SIZE,INPUT_SIZE,3)) # loss: 0.0149 - accuracy: 0.9956 - val_loss: 0.1836 - val_accuracy: 0.9750 - Test: 0.930272

print("Number of layers in the base model: ", len(base_model.layers))
    
base_model.trainable = True
    
base_model.summary()
    
last_output = base_model.output

x = GlobalAveragePooling2D()(last_output)
x = Dropout(rate=0.5)(x)

x = Flatten()(x)
x = Dense(4, activation='softmax')(x)
    
embedding_network = Model(inputs=[base_model.input], outputs=[x])
    
optimizer = Adam(learning_rate=0.00001) 
embedding_network.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=["accuracy"])
embedding_network.summary()
    
""" callbacks """
    
#early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    
checkpointer = ModelCheckpoint(filepath='embedding_network.h5', verbose=1, 
                                   save_best_only=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step
# Number of layers in the base model:  19
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 4)                 2052
#
# =================================================================
# Total params: 14,716,740
# Trainable params: 14,716,740
# Non-trainable params: 0
# _________________________________________________________________

# %%
""" Train the model """
    
history = embedding_network.fit(
    train_batches,
    validation_data = val_batches,
    epochs = 140,
    verbose = 1,
    shuffle = True,
    callbacks = [checkpointer]#, early_stopping]
)
    
""" plot the train and val accuracies """
# Plot the accuracy
utils.plt_metric(history=history.history, metric="accuracy", title="Model accuracy")
    
# Plot the constrastive loss
utils.plt_metric(history=history.history, metric="loss", title="Constrastive Loss")

    
print("End of Training, the model is saved to", MODEL_FNAME)
# Out:
# Epoch 1/140
# 86/86 [==============================] - ETA: 0s - loss: 1.1564 - accuracy: 0.4796
# Epoch 1: val_loss improved from inf to 0.76903, saving model to embedding_network.h5
# 86/86 [==============================] - 31s 170ms/step - loss: 1.1564 - accuracy: 0.4796 - val_loss: 0.7690 - val_accuracy: 0.7250
# Epoch 2/140
# 86/86 [==============================] - ETA: 0s - loss: 0.7322 - accuracy: 0.7194
# Epoch 2: val_loss improved from 0.76903 to 0.53816, saving model to embedding_network.h5
# 86/86 [==============================] - 11s 126ms/step - loss: 0.7322 - accuracy: 0.7194 - val_loss: 0.5382 - val_accuracy: 0.8000
# Epoch 3/140
# 86/86 [==============================] - ETA: 0s - loss: 0.5347 - accuracy: 0.8017
# Epoch 3: val_loss improved from 0.53816 to 0.51535, saving model to embedding_network.h5
# 86/86 [==============================] - 11s 125ms/step - loss: 0.5347 - accuracy: 0.8017 - val_loss: 0.5154 - val_accuracy: 0.7750
# Epoch 4/140
# 86/86 [==============================] - ETA: 0s - loss: 0.4207 - accuracy: 0.8550
# Epoch 4: val_loss improved from 0.51535 to 0.37397, saving model to embedding_network.h5
# 86/86 [==============================] - 11s 126ms/step - loss: 0.4207 - accuracy: 0.8550 - val_loss: 0.3740 - val_accuracy: 0.9000
# Epoch 5/140
# 86/86 [==============================] - ETA: 0s - loss: 0.3302 - accuracy: 0.8827
# Epoch 5: val_loss improved from 0.37397 to 0.34895, saving model to embedding_network.h5
# 86/86 [==============================] - 11s 127ms/step - loss: 0.3302 - accuracy: 0.8827 - val_loss: 0.3489 - val_accuracy: 0.8750
# Epoch 6/140
# 86/86 [==============================] - ETA: 0s - loss: 0.2469 - accuracy: 0.9103
# Epoch 6: val_loss improved from 0.34895 to 0.32898, saving model to embedding_network.h5
# 86/86 [==============================] - 11s 129ms/step - loss: 0.2469 - accuracy: 0.9103 - val_loss: 0.3290 - val_accuracy: 0.9000
# Epoch 7/140
# 86/86 [==============================] - ETA: 0s - loss: 0.2061 - accuracy: 0.9278
# Epoch 7: val_loss improved from 0.32898 to 0.29072, saving model to embedding_network.h5
# 86/86 [==============================] - 11s 127ms/step - loss: 0.2061 - accuracy: 0.9278 - val_loss: 0.2907 - val_accuracy: 0.9000
# Epoch 8/140
# 86/86 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.9395
# Epoch 8: val_loss did not improve from 0.29072
# 86/86 [==============================] - 11s 126ms/step - loss: 0.1795 - accuracy: 0.9395 - val_loss: 0.3398 - val_accuracy: 0.9000
# Epoch 9/140
# 86/86 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9475
# Epoch 9: val_loss did not improve from 0.29072
# 86/86 [==============================] - 11s 129ms/step - loss: 0.1576 - accuracy: 0.9475 - val_loss: 0.3492 - val_accuracy: 0.9000
# Epoch 10/140
# 86/86 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.9614
# Epoch 10: val_loss improved from 0.29072 to 0.20970, saving model to embedding_network.h5
# 86/86 [==============================] - 11s 132ms/step - loss: 0.1208 - accuracy: 0.9614 - val_loss: 0.2097 - val_accuracy: 0.9000
# Epoch 11/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 0.9716
# Epoch 11: val_loss did not improve from 0.20970
# 86/86 [==============================] - 11s 130ms/step - loss: 0.0850 - accuracy: 0.9716 - val_loss: 0.4106 - val_accuracy: 0.8750
# Epoch 12/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0710 - accuracy: 0.9767
# Epoch 12: val_loss did not improve from 0.20970
# 86/86 [==============================] - 11s 126ms/step - loss: 0.0710 - accuracy: 0.9767 - val_loss: 0.4489 - val_accuracy: 0.9250
# Epoch 13/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0626 - accuracy: 0.9818
# Epoch 13: val_loss did not improve from 0.20970
# 86/86 [==============================] - 11s 126ms/step - loss: 0.0626 - accuracy: 0.9818 - val_loss: 0.4935 - val_accuracy: 0.9250
# Epoch 14/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9810
# Epoch 14: val_loss did not improve from 0.20970
# 86/86 [==============================] - 11s 129ms/step - loss: 0.0616 - accuracy: 0.9810 - val_loss: 0.2569 - val_accuracy: 0.9000
# Epoch 15/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9869
# Epoch 15: val_loss did not improve from 0.20970
# 86/86 [==============================] - 11s 125ms/step - loss: 0.0373 - accuracy: 0.9869 - val_loss: 0.3908 - val_accuracy: 0.9000
# Epoch 16/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9825
# Epoch 16: val_loss improved from 0.20970 to 0.20414, saving model to embedding_network.h5
# 86/86 [==============================] - 11s 133ms/step - loss: 0.0504 - accuracy: 0.9825 - val_loss: 0.2041 - val_accuracy: 0.9000
# Epoch 17/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9920
# Epoch 17: val_loss did not improve from 0.20414
# 86/86 [==============================] - 11s 128ms/step - loss: 0.0397 - accuracy: 0.9920 - val_loss: 0.2698 - val_accuracy: 0.9250
# Epoch 18/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9942
# Epoch 18: val_loss did not improve from 0.20414
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0200 - accuracy: 0.9942 - val_loss: 0.3716 - val_accuracy: 0.9000
# Epoch 19/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9883
# Epoch 19: val_loss did not improve from 0.20414
# 86/86 [==============================] - 11s 129ms/step - loss: 0.0365 - accuracy: 0.9883 - val_loss: 0.4161 - val_accuracy: 0.9000
# Epoch 20/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9920
# Epoch 20: val_loss did not improve from 0.20414
# 86/86 [==============================] - 11s 128ms/step - loss: 0.0295 - accuracy: 0.9920 - val_loss: 0.3650 - val_accuracy: 0.9250
# Epoch 21/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9883
# Epoch 21: val_loss did not improve from 0.20414
# 86/86 [==============================] - 11s 128ms/step - loss: 0.0358 - accuracy: 0.9883 - val_loss: 0.2543 - val_accuracy: 0.9250
# Epoch 22/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9964
# Epoch 22: val_loss improved from 0.20414 to 0.16201, saving model to embedding_network.h5
# 86/86 [==============================] - 11s 131ms/step - loss: 0.0164 - accuracy: 0.9964 - val_loss: 0.1620 - val_accuracy: 0.9500
# Epoch 23/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9942
# Epoch 23: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 126ms/step - loss: 0.0208 - accuracy: 0.9942 - val_loss: 0.1675 - val_accuracy: 0.9750
# Epoch 24/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9934
# Epoch 24: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 128ms/step - loss: 0.0230 - accuracy: 0.9934 - val_loss: 0.3495 - val_accuracy: 0.9000
# Epoch 25/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9978
# Epoch 25: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 125ms/step - loss: 0.0110 - accuracy: 0.9978 - val_loss: 0.6693 - val_accuracy: 0.9000
# Epoch 26/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9978
# Epoch 26: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 129ms/step - loss: 0.0135 - accuracy: 0.9978 - val_loss: 0.3274 - val_accuracy: 0.9000
# Epoch 27/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9971
# Epoch 27: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0097 - accuracy: 0.9971 - val_loss: 0.3210 - val_accuracy: 0.9000
# Epoch 28/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9847
# Epoch 28: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 126ms/step - loss: 0.0401 - accuracy: 0.9847 - val_loss: 0.4205 - val_accuracy: 0.9250
# Epoch 29/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9964
# Epoch 29: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0154 - accuracy: 0.9964 - val_loss: 0.4327 - val_accuracy: 0.9250
# Epoch 30/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9985
# Epoch 30: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 128ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.2540 - val_accuracy: 0.9250
# Epoch 31/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9905
# Epoch 31: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 126ms/step - loss: 0.0182 - accuracy: 0.9905 - val_loss: 0.4781 - val_accuracy: 0.9250
# Epoch 32/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9934
# Epoch 32: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 128ms/step - loss: 0.0207 - accuracy: 0.9934 - val_loss: 0.5501 - val_accuracy: 0.9000
# Epoch 33/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9993
# Epoch 33: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 128ms/step - loss: 0.0057 - accuracy: 0.9993 - val_loss: 0.6022 - val_accuracy: 0.9000
# Epoch 34/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9985
# Epoch 34: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 126ms/step - loss: 0.0067 - accuracy: 0.9985 - val_loss: 0.4664 - val_accuracy: 0.9250
# Epoch 35/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9920
# Epoch 35: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0225 - accuracy: 0.9920 - val_loss: 0.2749 - val_accuracy: 0.8500
# Epoch 36/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9985
# Epoch 36: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 130ms/step - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.2968 - val_accuracy: 0.9250
# Epoch 37/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.9927
# Epoch 37: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 125ms/step - loss: 0.0310 - accuracy: 0.9927 - val_loss: 0.2733 - val_accuracy: 0.9250
# Epoch 38/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 38: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 130ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3499 - val_accuracy: 0.9250
# Epoch 39/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 39: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3759 - val_accuracy: 0.9250
# Epoch 40/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9993
# Epoch 40: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 125ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.3433 - val_accuracy: 0.9000
# Epoch 41/140
# 86/86 [==============================] - ETA: 0s - loss: 7.0676e-04 - accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 7.0676e-04 - accuracy: 1.0000 - val_loss: 0.3860 - val_accuracy: 0.9250
# Epoch 42/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 42: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 129ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3355 - val_accuracy: 0.9000
# Epoch 43/140
# 86/86 [==============================] - ETA: 0s - loss: 9.6191e-04 - accuracy: 1.0000
# Epoch 43: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 128ms/step - loss: 9.6191e-04 - accuracy: 1.0000 - val_loss: 0.4428 - val_accuracy: 0.9000
# Epoch 44/140
# 86/86 [==============================] - ETA: 0s - loss: 3.3915e-04 - accuracy: 1.0000
# Epoch 44: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 125ms/step - loss: 3.3915e-04 - accuracy: 1.0000 - val_loss: 0.5878 - val_accuracy: 0.9250
# Epoch 45/140
# 86/86 [==============================] - ETA: 0s - loss: 3.7843e-04 - accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 3.7843e-04 - accuracy: 1.0000 - val_loss: 0.5294 - val_accuracy: 0.9250
# Epoch 46/140
# 86/86 [==============================] - ETA: 0s - loss: 2.5387e-04 - accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 129ms/step - loss: 2.5387e-04 - accuracy: 1.0000 - val_loss: 0.5535 - val_accuracy: 0.9250
# Epoch 47/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9985
# Epoch 47: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.5328 - val_accuracy: 0.8750
# Epoch 48/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9920
# Epoch 48: val_loss did not improve from 0.16201
# 86/86 [==============================] - 12s 135ms/step - loss: 0.0321 - accuracy: 0.9920 - val_loss: 0.5831 - val_accuracy: 0.9000
# Epoch 49/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9825
# Epoch 49: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 128ms/step - loss: 0.0401 - accuracy: 0.9825 - val_loss: 0.3188 - val_accuracy: 0.9000
# Epoch 50/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9956
# Epoch 50: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0133 - accuracy: 0.9956 - val_loss: 0.2906 - val_accuracy: 0.9500
# Epoch 51/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9985
# Epoch 51: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 129ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.1867 - val_accuracy: 0.9250
# Epoch 52/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9985
# Epoch 52: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 130ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.4260 - val_accuracy: 0.9250
# Epoch 53/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9993
# Epoch 53: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.1747 - val_accuracy: 0.9500
# Epoch 54/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9985
# Epoch 54: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 126ms/step - loss: 0.0023 - accuracy: 0.9985 - val_loss: 0.2465 - val_accuracy: 0.9500
# Epoch 55/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9985
# Epoch 55: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0030 - accuracy: 0.9985 - val_loss: 0.2835 - val_accuracy: 0.9250
# Epoch 56/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9876
# Epoch 56: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0274 - accuracy: 0.9876 - val_loss: 0.3614 - val_accuracy: 0.9250
# Epoch 57/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 57: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2825 - val_accuracy: 0.9500
# Epoch 58/140
# 86/86 [==============================] - ETA: 0s - loss: 5.9256e-04 - accuracy: 1.0000
# Epoch 58: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 125ms/step - loss: 5.9256e-04 - accuracy: 1.0000 - val_loss: 0.3223 - val_accuracy: 0.9500
# Epoch 59/140
# 86/86 [==============================] - ETA: 0s - loss: 5.8149e-04 - accuracy: 1.0000
# Epoch 59: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 128ms/step - loss: 5.8149e-04 - accuracy: 1.0000 - val_loss: 0.4041 - val_accuracy: 0.9250
# Epoch 60/140
# 86/86 [==============================] - ETA: 0s - loss: 8.8090e-04 - accuracy: 1.0000
# Epoch 60: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 128ms/step - loss: 8.8090e-04 - accuracy: 1.0000 - val_loss: 0.4293 - val_accuracy: 0.9250
# Epoch 61/140
# 86/86 [==============================] - ETA: 0s - loss: 4.7751e-04 - accuracy: 1.0000
# Epoch 61: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 129ms/step - loss: 4.7751e-04 - accuracy: 1.0000 - val_loss: 0.2876 - val_accuracy: 0.9500
# Epoch 62/140
# 86/86 [==============================] - ETA: 0s - loss: 1.8182e-04 - accuracy: 1.0000
# Epoch 62: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 1.8182e-04 - accuracy: 1.0000 - val_loss: 0.4445 - val_accuracy: 0.9250
# Epoch 63/140
# 86/86 [==============================] - ETA: 0s - loss: 1.8882e-04 - accuracy: 1.0000
# Epoch 63: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 128ms/step - loss: 1.8882e-04 - accuracy: 1.0000 - val_loss: 0.3585 - val_accuracy: 0.9250
# Epoch 64/140
# 86/86 [==============================] - ETA: 0s - loss: 1.2771e-04 - accuracy: 1.0000
# Epoch 64: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 1.2771e-04 - accuracy: 1.0000 - val_loss: 0.4125 - val_accuracy: 0.9250
# Epoch 65/140
# 86/86 [==============================] - ETA: 0s - loss: 1.0878e-04 - accuracy: 1.0000
# Epoch 65: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 129ms/step - loss: 1.0878e-04 - accuracy: 1.0000 - val_loss: 0.5367 - val_accuracy: 0.9250
# Epoch 66/140
# 86/86 [==============================] - ETA: 0s - loss: 4.9344e-04 - accuracy: 1.0000
# Epoch 66: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 130ms/step - loss: 4.9344e-04 - accuracy: 1.0000 - val_loss: 0.6084 - val_accuracy: 0.9250
# Epoch 67/140
# 86/86 [==============================] - ETA: 0s - loss: 5.9015e-04 - accuracy: 1.0000
# Epoch 67: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 130ms/step - loss: 5.9015e-04 - accuracy: 1.0000 - val_loss: 0.3901 - val_accuracy: 0.9250
# Epoch 68/140
# 86/86 [==============================] - ETA: 0s - loss: 1.2170e-04 - accuracy: 1.0000
# Epoch 68: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 126ms/step - loss: 1.2170e-04 - accuracy: 1.0000 - val_loss: 0.4314 - val_accuracy: 0.9250
# Epoch 69/140
# 86/86 [==============================] - ETA: 0s - loss: 2.1265e-04 - accuracy: 1.0000
# Epoch 69: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 2.1265e-04 - accuracy: 1.0000 - val_loss: 0.2509 - val_accuracy: 0.9500
# Epoch 70/140
# 86/86 [==============================] - ETA: 0s - loss: 1.6506e-04 - accuracy: 1.0000
# Epoch 70: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 1.6506e-04 - accuracy: 1.0000 - val_loss: 0.5417 - val_accuracy: 0.9250
# Epoch 71/140
# 86/86 [==============================] - ETA: 0s - loss: 3.8915e-04 - accuracy: 1.0000
# Epoch 71: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 128ms/step - loss: 3.8915e-04 - accuracy: 1.0000 - val_loss: 0.3447 - val_accuracy: 0.9250
# Epoch 72/140
# 86/86 [==============================] - ETA: 0s - loss: 3.0230e-04 - accuracy: 1.0000
# Epoch 72: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 3.0230e-04 - accuracy: 1.0000 - val_loss: 0.3818 - val_accuracy: 0.9250
# Epoch 73/140
# 86/86 [==============================] - ETA: 0s - loss: 6.1076e-04 - accuracy: 1.0000
# Epoch 73: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 6.1076e-04 - accuracy: 1.0000 - val_loss: 0.4084 - val_accuracy: 0.9500
# Epoch 74/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0814 - accuracy: 0.9752
# Epoch 74: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0814 - accuracy: 0.9752 - val_loss: 0.1631 - val_accuracy: 0.9500
# Epoch 75/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9993
# Epoch 75: val_loss did not improve from 0.16201
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0066 - accuracy: 0.9993 - val_loss: 0.2237 - val_accuracy: 0.9250
# Epoch 76/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9971
# Epoch 76: val_loss improved from 0.16201 to 0.12869, saving model to embedding_network.h5
# 86/86 [==============================] - 11s 130ms/step - loss: 0.0078 - accuracy: 0.9971 - val_loss: 0.1287 - val_accuracy: 0.9500
# Epoch 77/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 77: val_loss did not improve from 0.12869
# 86/86 [==============================] - 11s 133ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2863 - val_accuracy: 0.9500
# Epoch 78/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 78: val_loss improved from 0.12869 to 0.12815, saving model to embedding_network.h5
# 86/86 [==============================] - 11s 132ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9500
# Epoch 79/140
# 86/86 [==============================] - ETA: 0s - loss: 7.9549e-04 - accuracy: 0.9993
# Epoch 79: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 7.9549e-04 - accuracy: 0.9993 - val_loss: 0.4658 - val_accuracy: 0.9250
# Epoch 80/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9847
# Epoch 80: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0406 - accuracy: 0.9847 - val_loss: 0.4773 - val_accuracy: 0.9250
# Epoch 81/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9985
# Epoch 81: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 126ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.5743 - val_accuracy: 0.9250
# Epoch 82/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9993
# Epoch 82: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 129ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.5346 - val_accuracy: 0.9000
# Epoch 83/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 83: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 126ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3471 - val_accuracy: 0.9250
# Epoch 84/140
# 86/86 [==============================] - ETA: 0s - loss: 7.6778e-04 - accuracy: 1.0000
# Epoch 84: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 7.6778e-04 - accuracy: 1.0000 - val_loss: 0.5219 - val_accuracy: 0.9250
# Epoch 85/140
# 86/86 [==============================] - ETA: 0s - loss: 2.0567e-04 - accuracy: 1.0000
# Epoch 85: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 2.0567e-04 - accuracy: 1.0000 - val_loss: 0.4210 - val_accuracy: 0.9250
# Epoch 86/140
# 86/86 [==============================] - ETA: 0s - loss: 3.7813e-04 - accuracy: 1.0000
# Epoch 86: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 3.7813e-04 - accuracy: 1.0000 - val_loss: 0.7080 - val_accuracy: 0.9250
# Epoch 87/140
# 86/86 [==============================] - ETA: 0s - loss: 2.9276e-04 - accuracy: 1.0000
# Epoch 87: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 129ms/step - loss: 2.9276e-04 - accuracy: 1.0000 - val_loss: 0.3173 - val_accuracy: 0.9500
# Epoch 88/140
# 86/86 [==============================] - ETA: 0s - loss: 2.3019e-04 - accuracy: 1.0000
# Epoch 88: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 125ms/step - loss: 2.3019e-04 - accuracy: 1.0000 - val_loss: 0.5295 - val_accuracy: 0.9250
# Epoch 89/140
# 86/86 [==============================] - ETA: 0s - loss: 1.2351e-04 - accuracy: 1.0000
# Epoch 89: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 1.2351e-04 - accuracy: 1.0000 - val_loss: 0.4060 - val_accuracy: 0.9500
# Epoch 90/140
# 86/86 [==============================] - ETA: 0s - loss: 6.7610e-05 - accuracy: 1.0000
# Epoch 90: val_loss did not improve from 0.12815
# 86/86 [==============================] - 12s 134ms/step - loss: 6.7610e-05 - accuracy: 1.0000 - val_loss: 0.5056 - val_accuracy: 0.9250
# Epoch 91/140
# 86/86 [==============================] - ETA: 0s - loss: 4.9831e-05 - accuracy: 1.0000
# Epoch 91: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 4.9831e-05 - accuracy: 1.0000 - val_loss: 0.4928 - val_accuracy: 0.9250
# Epoch 92/140
# 86/86 [==============================] - ETA: 0s - loss: 2.5983e-04 - accuracy: 1.0000
# Epoch 92: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 2.5983e-04 - accuracy: 1.0000 - val_loss: 0.7055 - val_accuracy: 0.9250
# Epoch 93/140
# 86/86 [==============================] - ETA: 0s - loss: 9.9876e-05 - accuracy: 1.0000
# Epoch 93: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 9.9876e-05 - accuracy: 1.0000 - val_loss: 0.5776 - val_accuracy: 0.9250
# Epoch 94/140
# 86/86 [==============================] - ETA: 0s - loss: 6.0020e-05 - accuracy: 1.0000
# Epoch 94: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 6.0020e-05 - accuracy: 1.0000 - val_loss: 0.5444 - val_accuracy: 0.9250
# Epoch 95/140
# 86/86 [==============================] - ETA: 0s - loss: 1.1044e-04 - accuracy: 1.0000
# Epoch 95: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 129ms/step - loss: 1.1044e-04 - accuracy: 1.0000 - val_loss: 0.5708 - val_accuracy: 0.9250
# Epoch 96/140
# 86/86 [==============================] - ETA: 0s - loss: 4.7336e-05 - accuracy: 1.0000
# Epoch 96: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 129ms/step - loss: 4.7336e-05 - accuracy: 1.0000 - val_loss: 0.5369 - val_accuracy: 0.9250
# Epoch 97/140
# 86/86 [==============================] - ETA: 0s - loss: 2.3143e-05 - accuracy: 1.0000
# Epoch 97: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 130ms/step - loss: 2.3143e-05 - accuracy: 1.0000 - val_loss: 0.5712 - val_accuracy: 0.9250
# Epoch 98/140
# 86/86 [==============================] - ETA: 0s - loss: 1.5349e-05 - accuracy: 1.0000
# Epoch 98: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 1.5349e-05 - accuracy: 1.0000 - val_loss: 0.5749 - val_accuracy: 0.9250
# Epoch 99/140
# 86/86 [==============================] - ETA: 0s - loss: 3.3532e-04 - accuracy: 1.0000
# Epoch 99: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 3.3532e-04 - accuracy: 1.0000 - val_loss: 0.3094 - val_accuracy: 0.9500
# Epoch 100/140
# 86/86 [==============================] - ETA: 0s - loss: 2.8359e-05 - accuracy: 1.0000
# Epoch 100: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 2.8359e-05 - accuracy: 1.0000 - val_loss: 0.3629 - val_accuracy: 0.9250
# Epoch 101/140
# 86/86 [==============================] - ETA: 0s - loss: 3.6934e-05 - accuracy: 1.0000
# Epoch 101: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 3.6934e-05 - accuracy: 1.0000 - val_loss: 0.3907 - val_accuracy: 0.9250
# Epoch 102/140
# 86/86 [==============================] - ETA: 0s - loss: 1.8887e-04 - accuracy: 1.0000
# Epoch 102: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 129ms/step - loss: 1.8887e-04 - accuracy: 1.0000 - val_loss: 0.4468 - val_accuracy: 0.9500
# Epoch 103/140
# 86/86 [==============================] - ETA: 0s - loss: 9.2467e-05 - accuracy: 1.0000
# Epoch 103: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 130ms/step - loss: 9.2467e-05 - accuracy: 1.0000 - val_loss: 0.5039 - val_accuracy: 0.9250
# Epoch 104/140
# 86/86 [==============================] - ETA: 0s - loss: 2.0928e-05 - accuracy: 1.0000
# Epoch 104: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 130ms/step - loss: 2.0928e-05 - accuracy: 1.0000 - val_loss: 0.4326 - val_accuracy: 0.9500
# Epoch 105/140
# 86/86 [==============================] - ETA: 0s - loss: 2.0782e-05 - accuracy: 1.0000
# Epoch 105: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 2.0782e-05 - accuracy: 1.0000 - val_loss: 0.4245 - val_accuracy: 0.9250
# Epoch 106/140
# 86/86 [==============================] - ETA: 0s - loss: 4.7959e-05 - accuracy: 1.0000
# Epoch 106: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 4.7959e-05 - accuracy: 1.0000 - val_loss: 0.3077 - val_accuracy: 0.9500
# Epoch 107/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0871 - accuracy: 0.9694
# Epoch 107: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 0.0871 - accuracy: 0.9694 - val_loss: 0.4807 - val_accuracy: 0.9250
# Epoch 108/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9964
# Epoch 108: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0090 - accuracy: 0.9964 - val_loss: 0.6345 - val_accuracy: 0.9000
# Epoch 109/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9949
# Epoch 109: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0156 - accuracy: 0.9949 - val_loss: 0.3578 - val_accuracy: 0.9500
# Epoch 110/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 110: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.2720 - val_accuracy: 0.9750
# Epoch 111/140
# 86/86 [==============================] - ETA: 0s - loss: 9.8944e-04 - accuracy: 1.0000
# Epoch 111: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 126ms/step - loss: 9.8944e-04 - accuracy: 1.0000 - val_loss: 0.5587 - val_accuracy: 0.9250
# Epoch 112/140
# 86/86 [==============================] - ETA: 0s - loss: 6.1180e-04 - accuracy: 1.0000
# Epoch 112: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 6.1180e-04 - accuracy: 1.0000 - val_loss: 0.5117 - val_accuracy: 0.9500
# Epoch 113/140
# 86/86 [==============================] - ETA: 0s - loss: 3.0213e-04 - accuracy: 1.0000
# Epoch 113: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 3.0213e-04 - accuracy: 1.0000 - val_loss: 0.4391 - val_accuracy: 0.9500
# Epoch 114/140
# 86/86 [==============================] - ETA: 0s - loss: 3.7195e-04 - accuracy: 1.0000
# Epoch 114: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 3.7195e-04 - accuracy: 1.0000 - val_loss: 0.3951 - val_accuracy: 0.9250
# Epoch 115/140
# 86/86 [==============================] - ETA: 0s - loss: 6.2507e-04 - accuracy: 1.0000
# Epoch 115: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 125ms/step - loss: 6.2507e-04 - accuracy: 1.0000 - val_loss: 0.4941 - val_accuracy: 0.9500
# Epoch 116/140
# 86/86 [==============================] - ETA: 0s - loss: 1.0979e-04 - accuracy: 1.0000
# Epoch 116: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 132ms/step - loss: 1.0979e-04 - accuracy: 1.0000 - val_loss: 0.5504 - val_accuracy: 0.9250
# Epoch 117/140
# 86/86 [==============================] - ETA: 0s - loss: 2.1156e-04 - accuracy: 1.0000
# Epoch 117: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 129ms/step - loss: 2.1156e-04 - accuracy: 1.0000 - val_loss: 0.5344 - val_accuracy: 0.9500
# Epoch 118/140
# 86/86 [==============================] - ETA: 0s - loss: 8.4932e-05 - accuracy: 1.0000
# Epoch 118: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 126ms/step - loss: 8.4932e-05 - accuracy: 1.0000 - val_loss: 0.4876 - val_accuracy: 0.9500
# Epoch 119/140
# 86/86 [==============================] - ETA: 0s - loss: 9.4696e-05 - accuracy: 1.0000
# Epoch 119: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 9.4696e-05 - accuracy: 1.0000 - val_loss: 0.5757 - val_accuracy: 0.9500
# Epoch 120/140
# 86/86 [==============================] - ETA: 0s - loss: 8.3060e-05 - accuracy: 1.0000
# Epoch 120: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 8.3060e-05 - accuracy: 1.0000 - val_loss: 0.7770 - val_accuracy: 0.9250
# Epoch 121/140
# 86/86 [==============================] - ETA: 0s - loss: 1.0827e-04 - accuracy: 1.0000
# Epoch 121: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 126ms/step - loss: 1.0827e-04 - accuracy: 1.0000 - val_loss: 0.5601 - val_accuracy: 0.9500
# Epoch 122/140
# 86/86 [==============================] - ETA: 0s - loss: 1.7910e-04 - accuracy: 1.0000
# Epoch 122: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 1.7910e-04 - accuracy: 1.0000 - val_loss: 0.6403 - val_accuracy: 0.9250
# Epoch 123/140
# 86/86 [==============================] - ETA: 0s - loss: 3.2860e-05 - accuracy: 1.0000
# Epoch 123: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 3.2860e-05 - accuracy: 1.0000 - val_loss: 0.5995 - val_accuracy: 0.9500
# Epoch 124/140
# 86/86 [==============================] - ETA: 0s - loss: 6.3865e-05 - accuracy: 1.0000
# Epoch 124: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 6.3865e-05 - accuracy: 1.0000 - val_loss: 0.5454 - val_accuracy: 0.9500
# Epoch 125/140
# 86/86 [==============================] - ETA: 0s - loss: 4.1300e-05 - accuracy: 1.0000
# Epoch 125: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 129ms/step - loss: 4.1300e-05 - accuracy: 1.0000 - val_loss: 0.5257 - val_accuracy: 0.9500
# Epoch 126/140
# 86/86 [==============================] - ETA: 0s - loss: 2.4237e-05 - accuracy: 1.0000
# Epoch 126: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 126ms/step - loss: 2.4237e-05 - accuracy: 1.0000 - val_loss: 0.5316 - val_accuracy: 0.9500
# Epoch 127/140
# 86/86 [==============================] - ETA: 0s - loss: 4.2707e-05 - accuracy: 1.0000
# Epoch 127: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 131ms/step - loss: 4.2707e-05 - accuracy: 1.0000 - val_loss: 0.5938 - val_accuracy: 0.9500
# Epoch 128/140
# 86/86 [==============================] - ETA: 0s - loss: 1.6081e-05 - accuracy: 1.0000
# Epoch 128: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 1.6081e-05 - accuracy: 1.0000 - val_loss: 0.5835 - val_accuracy: 0.9500
# Epoch 129/140
# 86/86 [==============================] - ETA: 0s - loss: 2.9633e-05 - accuracy: 1.0000
# Epoch 129: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 2.9633e-05 - accuracy: 1.0000 - val_loss: 0.5665 - val_accuracy: 0.9500
# Epoch 130/140
# 86/86 [==============================] - ETA: 0s - loss: 1.3165e-05 - accuracy: 1.0000
# Epoch 130: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 126ms/step - loss: 1.3165e-05 - accuracy: 1.0000 - val_loss: 0.5490 - val_accuracy: 0.9500
# Epoch 131/140
# 86/86 [==============================] - ETA: 0s - loss: 7.6262e-05 - accuracy: 1.0000
# Epoch 131: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 7.6262e-05 - accuracy: 1.0000 - val_loss: 0.5944 - val_accuracy: 0.9250
# Epoch 132/140
# 86/86 [==============================] - ETA: 0s - loss: 5.8385e-05 - accuracy: 1.0000
# Epoch 132: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 129ms/step - loss: 5.8385e-05 - accuracy: 1.0000 - val_loss: 0.5457 - val_accuracy: 0.9500
# Epoch 133/140
# 86/86 [==============================] - ETA: 0s - loss: 1.7771e-05 - accuracy: 1.0000
# Epoch 133: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 1.7771e-05 - accuracy: 1.0000 - val_loss: 0.5683 - val_accuracy: 0.9500
# Epoch 134/140
# 86/86 [==============================] - ETA: 0s - loss: 1.6110e-04 - accuracy: 1.0000
# Epoch 134: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 1.6110e-04 - accuracy: 1.0000 - val_loss: 0.4430 - val_accuracy: 0.9500
# Epoch 135/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9730
# Epoch 135: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 130ms/step - loss: 0.0881 - accuracy: 0.9730 - val_loss: 0.2207 - val_accuracy: 0.9500
# Epoch 136/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9876
# Epoch 136: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 0.0329 - accuracy: 0.9876 - val_loss: 0.4503 - val_accuracy: 0.9250
# Epoch 137/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 137: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2347 - val_accuracy: 0.9500
# Epoch 138/140
# 86/86 [==============================] - ETA: 0s - loss: 4.5349e-04 - accuracy: 1.0000
# Epoch 138: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 127ms/step - loss: 4.5349e-04 - accuracy: 1.0000 - val_loss: 0.3032 - val_accuracy: 0.9500
# Epoch 139/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 139: val_loss did not improve from 0.12815
# 86/86 [==============================] - 14s 159ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2893 - val_accuracy: 0.9250
# Epoch 140/140
# 86/86 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9985
# Epoch 140: val_loss did not improve from 0.12815
# 86/86 [==============================] - 11s 128ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.5140 - val_accuracy: 0.8750
# End of Training, the model is saved to embedding_network.h5

# %%
test_batches = ImageDataGenerator(rescale = 1 / 255.).flow_from_directory(test_dir,
                                                        target_size=(INPUT_SIZE,INPUT_SIZE),
                                                        class_mode='categorical',
                                                        shuffle=False,
                                                        seed=42,
                                                        batch_size=BATCH_SIZE)
    

test_glioma_dir = os.path.join(test_dir, 'glioma_tumor')
test_meningioma_dir = os.path.join(test_dir, 'meningioma_tumor')
test_normal_dir = os.path.join(test_dir, 'no_tumor')
test_pituitary_dir = os.path.join(test_dir, 'pituitary_tumor')
    
num_glioma_test = int(len(os.listdir(test_glioma_dir)))
num_meningioma_test = int(len(os.listdir(test_meningioma_dir)))
num_normal_test = int(len(os.listdir(test_normal_dir)))
num_pituitary_test = int(len(os.listdir(test_pituitary_dir)))

print('\nThe test set contains:')
print('\u2022 {} glioma images'.format(num_glioma_test))
print('\u2022 {} meningioma images'.format(num_meningioma_test))
print('\u2022 {} normal images'.format(num_normal_test))
print('\u2022 {} pituitary images'.format(num_pituitary_test))

""" Test the model """
model = tf.keras.models.load_model(MODEL_FNAME)
model.summary()
    
y_test = test_batches.classes
    
#Confution Matrix and Classification Report
Y_pred = model.predict_generator(test_batches, (num_glioma_test + num_meningioma_test + num_normal_test + num_pituitary_test) // BATCH_SIZE+1)
y_pred = np.argmax(Y_pred, axis=1)
    
class_labels = list(test_batches.class_indices.keys())   
    
cm = confusion_matrix(test_batches.classes, y_pred)    
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels).plot()
    
# results = model.evaluate_generator(test_batches)
print("\nEvaluate on test data")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, average='weighted'))
print("Recall:", recall_score(y_test, y_pred, average='weighted'))
    
tf.keras.backend.clear_session()
# Out:
# Found 588 images belonging to 4 classes.
#
# The test set contains:
# • 147 glioma images
# • 147 meningioma images
# • 147 normal images
# • 147 pituitary images
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 4)                 2052
#
# =================================================================
# Total params: 14,716,740
# Trainable params: 14,716,740
# Non-trainable params: 0
# _________________________________________________________________
#
# Evaluate on test data
# Accuracy: 0.9370748299319728
# Precision: 0.9371511147732052
# Recall: 0.9370748299319728

# %% [markdown]
# Siamese Network

# %%
# -*- coding: utf-8 -*-
import utils

import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, Flatten, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, roc_auc_score, f1_score

import numpy as np
import os

from keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

import logging

MARGIN = 0.2

tf.random.set_seed(0)
tf.keras.utils.set_random_seed(0)

logger = tf.get_logger()
logger.setLevel(logging.ERROR)

print('Using:')
print('\t\u2022 TensorFlow version:', tf.__version__)
print('\t\u2022 tf.keras version:', tf.keras.__version__)
print('\t\u2022 Running on GPU' if tf.test.is_gpu_available() else '\t\u2022 GPU device not found. Running on CPU')
# Out:
# Using:
# 	• TensorFlow version: 2.12.0
# 	• tf.keras version: 2.12.0
# 	• Running on GPU

# %%
INPUT_SIZE = 150

basedir = os.path.join("dataset", "siamese") 

train_image_list, train_y_list = utils.load_images(basedir, 'train', (INPUT_SIZE,INPUT_SIZE))
print("The train set contains",len(train_image_list)) 

valid_image_list, valid_y_list = utils.load_images(basedir, 'validation', (INPUT_SIZE,INPUT_SIZE))   
print("The valid set contains", len(valid_image_list))  

test_image_list, test_y_list = utils.load_images(basedir, 'test', (INPUT_SIZE,INPUT_SIZE))   
print("The test set contains", len(test_image_list))  

# make train triples
triples_train, labels_train = utils.make_triples(train_image_list, train_y_list)

# make validation triples
triples_val, labels_val = utils.make_triples(valid_image_list, valid_y_list)

# make test triples
triples_test, labels_test = utils.make_triples(test_image_list, test_y_list)

x_train_1 = triples_train[:, 0]  
x_train_2 = triples_train[:, 1]
x_train_3 = triples_train[:, 2]
print("number of triples for training", np.shape(x_train_1)[0]) 

x_val_1 = triples_val[:, 0] 
x_val_2 = triples_val[:, 1]
x_val_3 = triples_val[:, 2]
print("number of triples for validation", np.shape(x_val_1)[0]) 

x_test_1 = triples_test[:, 0] 
x_test_2 = triples_test[:, 1]
x_test_3 = triples_test[:, 2]
print("number of triples for test", np.shape(x_test_1)[0]) 

# utils.visualize(triples_train[:-1], labels_train[:-1], to_show=4, num_col=4)

tf.compat.v1.reset_default_graph()
# Out:
# Found 40 images belonging to 4 classes.
# The train set contains 40
# Found 40 images belonging to 4 classes.
# The valid set contains 40
# Found 1920 images belonging to 4 classes.
# The test set contains 1920
# number of triples for training 40
# number of triples for validation 40
# number of triples for test 1920

# %%
SIAMESE_MODEL_FNAME = 'siamese_network.h5'
EMBEDDING_MODEL_FNAME = 'embedding_network.h5'


embedding_network = tf.keras.models.load_model(EMBEDDING_MODEL_FNAME)
embedding_network.trainable = False

model = tf.keras.Sequential() 
for layer in embedding_network.layers:  
    model.add(layer) 

model.add(Flatten(name='flat'))
model.add(Dense(5120, name='den', activation='sigmoid', kernel_regularizer='l2')) 



# Define the tensors for the triplet of input images
anchor_input = tf.keras.layers.Input((INPUT_SIZE,INPUT_SIZE,3), name="anchor_input")
positive_input = tf.keras.layers.Input((INPUT_SIZE,INPUT_SIZE,3), name="positive_input")
negative_input = tf.keras.layers.Input((INPUT_SIZE,INPUT_SIZE,3), name="negative_input")

# Generate the embedding outputs 
encoded_anchor = model(anchor_input)
encoded_positive = model(positive_input)
encoded_negative = model(negative_input)

inputs = [anchor_input, positive_input, negative_input]
outputs = [encoded_anchor, encoded_positive, encoded_negative]
#x = tf.keras.layers.Lambda(lambda x: tf.math.l2_normalize(outputs, axis=1))(outputs)


loss = Lambda(utils.loss2(MARGIN))(outputs) 
# Connect the inputs with the outputs
siamese = Model(inputs=inputs,outputs=loss)

siamese.summary()

""" callbacks """

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, min_delta=0.0001)

checkpointer = ModelCheckpoint(filepath=SIAMESE_MODEL_FNAME, verbose=1, 
                                save_best_only=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  anchor_input (InputLayer)      [(None, 150, 150, 3  0           []
#                                 )]
#
#  positive_input (InputLayer)    [(None, 150, 150, 3  0           []
#                                 )]
#
#  negative_input (InputLayer)    [(None, 150, 150, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 5120)         14742340    ['anchor_input[0][0]',
#                                                                   'positive_input[0][0]',
#                                                                   'negative_input[0][0]']
#
#  lambda (Lambda)                (None,)              0           ['sequential[0][0]',
#                                                                   'sequential[1][0]',
#                                                                   'sequential[2][0]']
#
# ==================================================================================================
# Total params: 14,742,340
# Trainable params: 25,600
# Non-trainable params: 14,716,740
# __________________________________________________________________________________________________

# %%
""" train the model """
optimizer = Adam(learning_rate=0.0001)
#siamese.compile(loss=utils.loss(1), optimizer=optimizer, metrics=["accuracy"]) # Manhattan [loss: 0.0997 - accuracy: 0.9539] | Euclidean [loss: 0.2267 - accuracy: 0.9487]
# siamese.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), optimizer=optimizer, metrics=["accuracy"]) # Manhattan [loss: 0.4305 - accuracy: 0.9430] | Euclidean [loss: 0.6142 - accuracy: 0.9464]

# Compile the model
siamese.compile(
    optimizer=optimizer,
    loss=utils.identity_loss)

siamese.summary()
history = siamese.fit([x_train_1, x_train_2, x_train_3],
    labels_train[:,0].reshape(-1, 1),
    validation_data=([x_val_1, x_val_2, x_val_3], labels_val[:,0].reshape(-1, 1)),
    batch_size=1,
    epochs=175,   # 175 for contrastive 100 for cross ent
    callbacks = [checkpointer, reduce_lr]#, early_stopping]
)

# Plot the Triplet loss
utils.plt_metric(history=history.history, metric="loss", title="Triplet Loss")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  anchor_input (InputLayer)      [(None, 150, 150, 3  0           []
#                                 )]
#
#  positive_input (InputLayer)    [(None, 150, 150, 3  0           []
#                                 )]
#
#  negative_input (InputLayer)    [(None, 150, 150, 3  0           []
#                                 )]
#
#  sequential_1 (Sequential)      (None, 5120)         14742340    ['anchor_input[0][0]',
#                                                                   'positive_input[0][0]',
#                                                                   'negative_input[0][0]']
#
#  lambda (Lambda)                (None,)              0           ['sequential_1[0][0]',
#                                                                   'sequential_1[1][0]',
#                                                                   'sequential_1[2][0]']
#
# ==================================================================================================
# Total params: 14,742,340
# Trainable params: 25,600
# Non-trainable params: 14,716,740
# __________________________________________________________________________________________________
# Epoch 1/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1130
# Epoch 1: val_loss improved from inf to 0.09323, saving model to siamese_network.h5
# 40/40 [==============================] - 4s 51ms/step - loss: 0.1130 - val_loss: 0.0932 - lr: 1.0000e-04
# Epoch 2/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1006
# Epoch 2: val_loss improved from 0.09323 to 0.08998, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 55ms/step - loss: 0.1006 - val_loss: 0.0900 - lr: 1.0000e-04
# Epoch 3/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0994
# Epoch 3: val_loss improved from 0.08998 to 0.08913, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0994 - val_loss: 0.0891 - lr: 1.0000e-04
# Epoch 4/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0907
# Epoch 4: val_loss improved from 0.08913 to 0.08538, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 58ms/step - loss: 0.0907 - val_loss: 0.0854 - lr: 1.0000e-04
# Epoch 5/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0936
# Epoch 5: val_loss improved from 0.08538 to 0.08411, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0936 - val_loss: 0.0841 - lr: 1.0000e-04
# Epoch 6/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0894
# Epoch 6: val_loss did not improve from 0.08411
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0894 - val_loss: 0.0842 - lr: 1.0000e-04
# Epoch 7/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0903
# Epoch 7: val_loss did not improve from 0.08411
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0903 - val_loss: 0.0844 - lr: 1.0000e-04
# Epoch 8/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0910
# Epoch 8: val_loss improved from 0.08411 to 0.08253, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0910 - val_loss: 0.0825 - lr: 1.0000e-04
# Epoch 9/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0826
# Epoch 9: val_loss improved from 0.08253 to 0.08095, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0826 - val_loss: 0.0809 - lr: 1.0000e-04
# Epoch 10/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0810
# Epoch 10: val_loss improved from 0.08095 to 0.08069, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0810 - val_loss: 0.0807 - lr: 1.0000e-04
# Epoch 11/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0896
# Epoch 11: val_loss improved from 0.08069 to 0.08004, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 58ms/step - loss: 0.0896 - val_loss: 0.0800 - lr: 1.0000e-04
# Epoch 12/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0814
# Epoch 12: val_loss improved from 0.08004 to 0.07935, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0814 - val_loss: 0.0794 - lr: 1.0000e-04
# Epoch 13/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0850
# Epoch 13: val_loss improved from 0.07935 to 0.07856, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0850 - val_loss: 0.0786 - lr: 1.0000e-04
# Epoch 14/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0880
# Epoch 14: val_loss did not improve from 0.07856
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0880 - val_loss: 0.0790 - lr: 1.0000e-04
# Epoch 15/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0878
# Epoch 15: val_loss improved from 0.07856 to 0.07839, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0878 - val_loss: 0.0784 - lr: 1.0000e-04
# Epoch 16/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0854
# Epoch 16: val_loss improved from 0.07839 to 0.07823, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0854 - val_loss: 0.0782 - lr: 1.0000e-04
# Epoch 17/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0859
# Epoch 17: val_loss did not improve from 0.07823
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0859 - val_loss: 0.0794 - lr: 1.0000e-04
# Epoch 18/175
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0851
# Epoch 18: val_loss improved from 0.07823 to 0.07811, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 51ms/step - loss: 0.0834 - val_loss: 0.0781 - lr: 1.0000e-04
# Epoch 19/175
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0862
# Epoch 19: val_loss improved from 0.07811 to 0.07736, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0846 - val_loss: 0.0774 - lr: 1.0000e-04
# Epoch 20/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0830
# Epoch 20: val_loss did not improve from 0.07736
# 40/40 [==============================] - 2s 51ms/step - loss: 0.0830 - val_loss: 0.0778 - lr: 1.0000e-04
# Epoch 21/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0818
# Epoch 21: val_loss did not improve from 0.07736
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0818 - val_loss: 0.0782 - lr: 1.0000e-04
# Epoch 22/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0814
# Epoch 22: val_loss did not improve from 0.07736
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0814 - val_loss: 0.0781 - lr: 1.0000e-04
# Epoch 23/175
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0740
# Epoch 23: val_loss did not improve from 0.07736
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0814 - val_loss: 0.0783 - lr: 1.0000e-04
# Epoch 24/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0822
# Epoch 24: val_loss improved from 0.07736 to 0.07731, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0822 - val_loss: 0.0773 - lr: 1.0000e-04
# Epoch 25/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0773
# Epoch 25: val_loss improved from 0.07731 to 0.07704, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0773 - val_loss: 0.0770 - lr: 2.0000e-05
# Epoch 26/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0872
# Epoch 26: val_loss did not improve from 0.07704
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0872 - val_loss: 0.0771 - lr: 2.0000e-05
# Epoch 27/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0832
# Epoch 27: val_loss did not improve from 0.07704
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0832 - val_loss: 0.0772 - lr: 2.0000e-05
# Epoch 28/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0774
# Epoch 28: val_loss improved from 0.07704 to 0.07691, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0774 - val_loss: 0.0769 - lr: 2.0000e-05
# Epoch 29/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0802
# Epoch 29: val_loss did not improve from 0.07691
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0802 - val_loss: 0.0771 - lr: 2.0000e-05
# Epoch 30/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0846
# Epoch 30: val_loss did not improve from 0.07691
# 40/40 [==============================] - 2s 51ms/step - loss: 0.0846 - val_loss: 0.0772 - lr: 2.0000e-05
# Epoch 31/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0753
# Epoch 31: val_loss did not improve from 0.07691
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0753 - val_loss: 0.0770 - lr: 2.0000e-05
# Epoch 32/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0801
# Epoch 32: val_loss did not improve from 0.07691
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0801 - val_loss: 0.0769 - lr: 2.0000e-05
# Epoch 33/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0832
# Epoch 33: val_loss did not improve from 0.07691
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0832 - val_loss: 0.0770 - lr: 2.0000e-05
# Epoch 34/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0777
# Epoch 34: val_loss did not improve from 0.07691
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0777 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 35/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0896
# Epoch 35: val_loss did not improve from 0.07691
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0896 - val_loss: 0.0770 - lr: 1.0000e-05
# Epoch 36/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0842
# Epoch 36: val_loss did not improve from 0.07691
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0842 - val_loss: 0.0770 - lr: 1.0000e-05
# Epoch 37/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0800
# Epoch 37: val_loss did not improve from 0.07691
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0800 - val_loss: 0.0770 - lr: 1.0000e-05
# Epoch 38/175
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0842
# Epoch 38: val_loss did not improve from 0.07691
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0824 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 39/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0869
# Epoch 39: val_loss did not improve from 0.07691
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0869 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 40/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0867
# Epoch 40: val_loss improved from 0.07691 to 0.07689, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0867 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 41/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0834
# Epoch 41: val_loss improved from 0.07689 to 0.07688, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0834 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 42/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0880
# Epoch 42: val_loss did not improve from 0.07688
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0880 - val_loss: 0.0770 - lr: 1.0000e-05
# Epoch 43/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0838
# Epoch 43: val_loss did not improve from 0.07688
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0838 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 44/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0825
# Epoch 44: val_loss improved from 0.07688 to 0.07683, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0825 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 45/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0820
# Epoch 45: val_loss improved from 0.07683 to 0.07683, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0820 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 46/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0828
# Epoch 46: val_loss did not improve from 0.07683
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0828 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 47/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0821
# Epoch 47: val_loss improved from 0.07683 to 0.07682, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0821 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 48/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0833
# Epoch 48: val_loss improved from 0.07682 to 0.07680, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0833 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 49/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0862
# Epoch 49: val_loss did not improve from 0.07680
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0862 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 50/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0829
# Epoch 50: val_loss did not improve from 0.07680
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0829 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 51/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0810
# Epoch 51: val_loss improved from 0.07680 to 0.07679, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0810 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 52/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0835
# Epoch 52: val_loss did not improve from 0.07679
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0835 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 53/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0838
# Epoch 53: val_loss did not improve from 0.07679
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0838 - val_loss: 0.0770 - lr: 1.0000e-05
# Epoch 54/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0850
# Epoch 54: val_loss did not improve from 0.07679
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0850 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 55/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0773
# Epoch 55: val_loss did not improve from 0.07679
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0773 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 56/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0895
# Epoch 56: val_loss did not improve from 0.07679
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0895 - val_loss: 0.0770 - lr: 1.0000e-05
# Epoch 57/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0871
# Epoch 57: val_loss did not improve from 0.07679
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0871 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 58/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0750
# Epoch 58: val_loss improved from 0.07679 to 0.07679, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0750 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 59/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0813
# Epoch 59: val_loss did not improve from 0.07679
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0813 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 60/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0803
# Epoch 60: val_loss did not improve from 0.07679
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0803 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 61/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0736
# Epoch 61: val_loss did not improve from 0.07679
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0736 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 62/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0827
# Epoch 62: val_loss did not improve from 0.07679
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0827 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 63/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0882
# Epoch 63: val_loss did not improve from 0.07679
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0882 - val_loss: 0.0770 - lr: 1.0000e-05
# Epoch 64/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0870
# Epoch 64: val_loss did not improve from 0.07679
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0870 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 65/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0820
# Epoch 65: val_loss did not improve from 0.07679
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0820 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 66/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0828
# Epoch 66: val_loss improved from 0.07679 to 0.07669, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0828 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 67/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0872
# Epoch 67: val_loss did not improve from 0.07669
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0872 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 68/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0785
# Epoch 68: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0785 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 69/175
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0785
# Epoch 69: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0770 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 70/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0819
# Epoch 70: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0819 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 71/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0825
# Epoch 71: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0825 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 72/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0842
# Epoch 72: val_loss did not improve from 0.07669
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0842 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 73/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0856
# Epoch 73: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0856 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 74/175
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0797
# Epoch 74: val_loss did not improve from 0.07669
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0785 - val_loss: 0.0770 - lr: 1.0000e-05
# Epoch 75/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0839
# Epoch 75: val_loss did not improve from 0.07669
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0839 - val_loss: 0.0770 - lr: 1.0000e-05
# Epoch 76/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0768
# Epoch 76: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0768 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 77/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0766
# Epoch 77: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0766 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 78/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0831
# Epoch 78: val_loss did not improve from 0.07669
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0831 - val_loss: 0.0770 - lr: 1.0000e-05
# Epoch 79/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0866
# Epoch 79: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0866 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 80/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0875
# Epoch 80: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0875 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 81/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0885
# Epoch 81: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0885 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 82/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0829
# Epoch 82: val_loss did not improve from 0.07669
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0829 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 83/175
# 39/40 [============================>.] - ETA: 0s - loss: 0.0816
# Epoch 83: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0807 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 84/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0719
# Epoch 84: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0719 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 85/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0799
# Epoch 85: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0799 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 86/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0796
# Epoch 86: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0796 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 87/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0831
# Epoch 87: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0831 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 88/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0843
# Epoch 88: val_loss did not improve from 0.07669
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0843 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 89/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0833
# Epoch 89: val_loss did not improve from 0.07669
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0833 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 90/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0831
# Epoch 90: val_loss did not improve from 0.07669
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0831 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 91/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0768
# Epoch 91: val_loss improved from 0.07669 to 0.07668, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0768 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 92/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0837
# Epoch 92: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0837 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 93/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0749
# Epoch 93: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0749 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 94/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0826
# Epoch 94: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0826 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 95/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0865
# Epoch 95: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0865 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 96/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0854
# Epoch 96: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0854 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 97/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0784
# Epoch 97: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0784 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 98/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0887
# Epoch 98: val_loss did not improve from 0.07668
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0887 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 99/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0828
# Epoch 99: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0828 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 100/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0809
# Epoch 100: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0809 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 101/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0861
# Epoch 101: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0861 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 102/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0903
# Epoch 102: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0903 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 103/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0816
# Epoch 103: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0816 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 104/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0849
# Epoch 104: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0849 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 105/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0767
# Epoch 105: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0767 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 106/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0792
# Epoch 106: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0792 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 107/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0872
# Epoch 107: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0872 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 108/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0823
# Epoch 108: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0823 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 109/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0810
# Epoch 109: val_loss did not improve from 0.07668
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0810 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 110/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0851
# Epoch 110: val_loss improved from 0.07668 to 0.07665, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0851 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 111/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0939
# Epoch 111: val_loss did not improve from 0.07665
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0939 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 112/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0777
# Epoch 112: val_loss did not improve from 0.07665
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0777 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 113/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0836
# Epoch 113: val_loss did not improve from 0.07665
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0836 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 114/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0762
# Epoch 114: val_loss did not improve from 0.07665
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0762 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 115/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0812
# Epoch 115: val_loss did not improve from 0.07665
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0812 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 116/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0833
# Epoch 116: val_loss did not improve from 0.07665
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0833 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 117/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0768
# Epoch 117: val_loss improved from 0.07665 to 0.07662, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0768 - val_loss: 0.0766 - lr: 1.0000e-05
# Epoch 118/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0823
# Epoch 118: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0823 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 119/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0815
# Epoch 119: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0815 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 120/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0850
# Epoch 120: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0850 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 121/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0800
# Epoch 121: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0800 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 122/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0826
# Epoch 122: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0826 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 123/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0950
# Epoch 123: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0950 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 124/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0829
# Epoch 124: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0829 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 125/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0853
# Epoch 125: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0853 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 126/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0810
# Epoch 126: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0810 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 127/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0825
# Epoch 127: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0825 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 128/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0808
# Epoch 128: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0808 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 129/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0856
# Epoch 129: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0856 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 130/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0833
# Epoch 130: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0833 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 131/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0828
# Epoch 131: val_loss improved from 0.07662 to 0.07662, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0828 - val_loss: 0.0766 - lr: 1.0000e-05
# Epoch 132/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0832
# Epoch 132: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0832 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 133/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0855
# Epoch 133: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0855 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 134/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0796
# Epoch 134: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0796 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 135/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0841
# Epoch 135: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0841 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 136/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0884
# Epoch 136: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0884 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 137/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0790
# Epoch 137: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0790 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 138/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0822
# Epoch 138: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0822 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 139/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0860
# Epoch 139: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0860 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 140/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0864
# Epoch 140: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0864 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 141/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0858
# Epoch 141: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0858 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 142/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0844
# Epoch 142: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0844 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 143/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0840
# Epoch 143: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0840 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 144/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0831
# Epoch 144: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0831 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 145/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0856
# Epoch 145: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0856 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 146/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0851
# Epoch 146: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0851 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 147/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0797
# Epoch 147: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0797 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 148/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0801
# Epoch 148: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0801 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 149/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0767
# Epoch 149: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0767 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 150/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0825
# Epoch 150: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0825 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 151/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0863
# Epoch 151: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0863 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 152/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0857
# Epoch 152: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0857 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 153/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0799
# Epoch 153: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0799 - val_loss: 0.0766 - lr: 1.0000e-05
# Epoch 154/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0844
# Epoch 154: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0844 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 155/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0838
# Epoch 155: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0838 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 156/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0852
# Epoch 156: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0852 - val_loss: 0.0769 - lr: 1.0000e-05
# Epoch 157/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0877
# Epoch 157: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0877 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 158/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0826
# Epoch 158: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0826 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 159/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0841
# Epoch 159: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0841 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 160/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0791
# Epoch 160: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0791 - val_loss: 0.0766 - lr: 1.0000e-05
# Epoch 161/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0892
# Epoch 161: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0892 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 162/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0725
# Epoch 162: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0725 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 163/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0811
# Epoch 163: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0811 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 164/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0842
# Epoch 164: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0842 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 165/175
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0867
# Epoch 165: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0848 - val_loss: 0.0768 - lr: 1.0000e-05
# Epoch 166/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0884
# Epoch 166: val_loss did not improve from 0.07662
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0884 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 167/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0862
# Epoch 167: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0862 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 168/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0821
# Epoch 168: val_loss did not improve from 0.07662
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0821 - val_loss: 0.0766 - lr: 1.0000e-05
# Epoch 169/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0849
# Epoch 169: val_loss improved from 0.07662 to 0.07659, saving model to siamese_network.h5
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0849 - val_loss: 0.0766 - lr: 1.0000e-05
# Epoch 170/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0862
# Epoch 170: val_loss did not improve from 0.07659
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0862 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 171/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0779
# Epoch 171: val_loss did not improve from 0.07659
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0779 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 172/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0806
# Epoch 172: val_loss did not improve from 0.07659
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0806 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 173/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0872
# Epoch 173: val_loss did not improve from 0.07659
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0872 - val_loss: 0.0767 - lr: 1.0000e-05
# Epoch 174/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0791
# Epoch 174: val_loss did not improve from 0.07659
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0791 - val_loss: 0.0766 - lr: 1.0000e-05
# Epoch 175/175
# 40/40 [==============================] - ETA: 0s - loss: 0.0859
# Epoch 175: val_loss did not improve from 0.07659
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0859 - val_loss: 0.0767 - lr: 1.0000e-05

# %%
""" Test the model """
siamese = tf.keras.models.load_model(SIAMESE_MODEL_FNAME, custom_objects={'identity_loss': identity_loss})

results = siamese.evaluate([x_test_1, x_test_2, x_test_3], labels_test)
print("test loss", results)

Y_pred = siamese.predict([x_test_1, x_test_2, x_test_3]).squeeze()


print("\nEvaluate on test data")
print("Accuracy:", len(np.where(Y_pred <= MARGIN)[0]) / len(Y_pred))

tf.keras.backend.clear_session()
# Out:
# 60/60 [==============================] - 24s 210ms/step - loss: 0.0680
# test loss 0.06801939755678177
# 60/60 [==============================] - 13s 216ms/step
#
# Evaluate on test data
# Accuracy: 0.975
